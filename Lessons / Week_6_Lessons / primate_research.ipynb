# %% [markdown]
# <a href="https://colab.research.google.com/github/ThandoZwane06/Cisco-Data-Science-Essentials/blob/main/Lessons%20/%20Week_6_Lessons%20/%20primate_research.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Primate Research
#
# Can books change cultures?
#
# The 1975 publication of the book Animal Liberation by Peter Singer is often credited with sparking an animal rights movement. Did it? Let's look at word usage data to explore this claim? We will focus on primates used in biomedical research.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b500e447-9850-4ec3-b5e2-9cbd130a4cec" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b500e447-9850-4ec3-b5e2-9cbd130a4cec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('animal-word-trends-primate-research.csv')
df.head()
# Out:
#    year      word  frequency
# 0  1900    baboon   0.500520
# 1  1900  marmoset   0.098320
# 2  1900   primate   1.652149
# 3  1900    rhesus   0.110651
# 4  1901    baboon   0.505336

# %%
def plot_word_trend( animal ):
    trend = df.query('word == @animal')
    plt.figure(figsize=(5, 3))
    plt.plot(trend['year'], trend['frequency'], label=animal)
    plt.ylabel('Frequency per million')
    plt.title(f'Word usage for "{animal}" and year Animal Liberation book published')
    plt.axvline(1975, color='orange', ls='--')

# %% [markdown]
# Explore word trends for primates used in research.

# %%
plot_word_trend('primate')
# try primate, marmoset, baboon, rhesus

# %%
plot_word_trend('marmoset')

# %%
plot_word_trend('baboon')

# %%
plot_word_trend('rhesus')

# %% [markdown]
# ### How animal research changed
#
# Let's look at another dataset to see what was happening with the research.

# %%
counts = pd.read_csv('number-of-research-animals-per-year.csv')
counts.head(2)
# Out:
#    year  primates    dogs   cats  rabbits  guinea_pigs  hamsters
# 0  1973     42298  195157  66195   447570       408970    454986
# 1  1974     51253  199204  74259   425585       430439    430766

# %%
def plot_animal_research( animal ):
	plt.figure(figsize=(5, 3))
	plt.plot(counts['year'], counts[animal])
	plt.axvline(1975, label='Animal Liberation book', color='orange', ls='--')
	plt.ylabel('Number of animals')
	plt.title(f'Number of {animal} used in research per year')
	plt.legend()
	plt.show()

plot_animal_research('primates')

# %% [markdown]
# 1. Pre-Publication of the book word frequency of "primate" was low, hovering around 1 and 1.5 per million. There was an exponential surge around 1960 which peaked in 1975 at 5.5 per million, which matches the publication of the ***Animal Liberation*** book. Post-publication of the book the word frequency for primates slightly decreased.
#
# 2. In 1975 text frequency of the word "primate" were at an all time high, yet the actual usage of primates was at its lowest roughly 36 000. This indicates the spike was driven by ethical debates, activism, and legislative discussions around the book, rather than the actual scientific laboratory activity.
#
# 3. Tone Druglitrø’s (2023) research indicates that the surge in "primate" usage in literature during the 1960s and 1970s was driven by the World Health Organization’s (WHO) response to a crisis in wild-caught supply for vaccine development, which created significant zoonotic public health hazards. This linguistic trend stabilized post-1975 as institutions shifted toward biological standardization and regulated, domestic breeding, combining conservation concerns with new "cultures of care.
#
# 4.  The data shows that while Animal Liberation successfully sparked a philosophical and cultural shift (as proven by the massive word frequency usage), it failed to structurally reduce the physical use of animals in biomedical science.
